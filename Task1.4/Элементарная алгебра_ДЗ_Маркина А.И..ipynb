# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 121)
k1 = 1
k2 = float(input('Введите число k, не равное единице: '))
plt.plot(x, np.cos(k1*x), x, np.cos(k2*x), '-.')

plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.grid()
# Out:
# Введите число k, не равное единице: 2
